# %% [markdown]
# ## Amelie: This code calculates seconds per hour and per day

# %%
# Number of seconds in an hour
60 * 60
# Out:
# 3600

# %%
#The value is stored in a variable called seconds_per_hour
seconds_per_hour = 3600

# %%
# Number of seconds in a day
seconds_per_hour * 24
# Out:
# 86400

# %%
#The result is stored in a variable called seconds_per_day
seconds_per_day = seconds_per_hour * 24

# %%
#We divide seconds per day by seconds per hour
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %%
# Let's divide seconds_per_day by seconds_per_hour
seconds_per_day // seconds_per_hour
# Out:
# 24

# %% [markdown]
# # Yes, the result agrees with the previous value. The only difference is that integer division returns 24 instead of 24.0.
