# %% [markdown]
# Amelie Mbouna Djouda: This code calculates seconds per hour and per day

# %% [markdown]
# 3.1. Number of seconds in an hour. There are 3600 seconds in an hour

# %%
60 * 60

# %% [markdown]
# 3.2. The value is stored in a variable called seconds_per_hour.

# %%
seconds_per_hour = 3600

# %% [markdown]
# 3.3. Number of seconds in a day: There are 86400 seconds in a day

# %%
seconds_per_hour * 24
# Out:
# 86400

# %% [markdown]
# 3.4 The result is stored in a variable called seconds_per_day.

# %%
seconds_per_day = seconds_per_hour * 24

# %% [markdown]
# 3.5. Dividing seconds per day by seconds per hour gives 24.0

# %%
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %% [markdown]
# 3.6. Yes, the result agrees with the previous value.
# The only difference is that integer division returns 24 instead of 24.0.

# %%
seconds_per_day // seconds_per_hour
# Out:
# 24
